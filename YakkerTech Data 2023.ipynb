# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
game022423 = pd.read_csv("YakkertechData/02_24_2023 10_28_53 AM-Nevada Las Vegas@UC San Diego.csv")
game022623 = pd.read_csv("YakkertechData/02_26_2023 4_51_20 PM-Washington State@UC San Diego.csv")
game0227231 = pd.read_csv("YakkertechData/02_27_2023 11_55_47 AM-North Dakota State@UC San Diego.csv")
game0227232 = pd.read_csv("YakkertechData/02_27_2023 3_30_49 PM-North Dakota State@UC San Diego.csv")
game0227233 = pd.read_csv("YakkertechData/02_27_2023 6_13_41 PM-North Dakota State@UC San Diego.csv")
game0303231 = pd.read_csv("YakkertechData/03_03_2023 5_23_28 PM-Santa Clara@UC San Diego.csv")
game0303232 = pd.read_csv("YakkertechData/03_03_2023 6_09_00 PM-Santa Clara@UC San Diego.csv")
game0303233 = pd.read_csv("YakkertechData/03_03_2023 7_03_37 PM-Santa Clara@UC San Diego.csv")
game0303234 = pd.read_csv("YakkertechData/03_03_2023 7_45_02 PM-Santa Clara@UC San Diego.csv")
game030423 = pd.read_csv("YakkertechData/03_04_2023 1_56_14 PM-Santa Clara@UC San Diego.csv")
game030523 = pd.read_csv("YakkertechData/03_05_2023 12_03_19 PM-Santa Clara@UC San Diego.csv")
game031023 = pd.read_csv("YakkertechData/03_10_2023 11_45_40 AM-Northern Colorado@UC San Diego.csv")
game0312231 = pd.read_csv("YakkertechData/03_12_2023 3_06_31 PM-Northern Colorado@UC San Diego.csv")
game0312232 = pd.read_csv("YakkertechData/03_12_2023 5_45_33 PM-Northern Colorado@UC San Diego.csv")
game0314231 = pd.read_csv("YakkertechData/03_14_2023 3_45_18 PM-UC Riverside@UC San Diego.csv")
game0314232 = pd.read_csv("YakkertechData/03_14_2023 6_14_42 PM-UC Riverside@UC San Diego.csv")
game0314233 = pd.read_csv("YakkertechData/03_14_2023 6_16_27 PM-UC Riverside@UC San Diego.csv")
game031723 = pd.read_csv("YakkertechData/03_17_2023 5_47_48 PM-Long Beach State@UC San Diego.csv")
game031823 = pd.read_csv("YakkertechData/03_18_2023 1_55_45 PM-Long Beach State@UC San Diego.csv") 
game031923 = pd.read_csv("YakkertechData/03_19_2023 12_59_21 PM-Long Beach State@UC San Diego.csv")
game032823 = pd.read_csv("YakkertechData/03_28_2023 5_39_31 PM-San Diego State@UC San Diego.csv")
game032523 = pd.read_csv("YakkertechData/03_25_2023 1_44_09 PM-Cal State Bakersfield@UC San Diego.csv")
game032423 = pd.read_csv("YakkertechData/03_26_2023 12_50_33 PM-Cal State Bakersfield@UC San Diego.csv")
game032623 = pd.read_csv("YakkertechData/03_24_2023 5_57_04 PM-Cal State Bakersfield@UC San Diego.csv")

gamelst = [game022423, game022623, game0227231, game0227232, game0227233, game0303231, game0303232, game0303233, game0303234,
          game030423, game030523, game031023, game0312231, game0312232, game0314231, game0314232, game0314233, game031723,
          game031823, game031923, game032823, game032423, game032523, game032623]
data = pd.concat(gamelst)

# %%
ucsdPitcherData = data[data.PitcherTeam == 'Uc san diego']

# %%
rissasFB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Ryan Rissas') & (ucsdPitcherData.TaggedPitchType == 'Fastball')]
ernieFB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Zack Ernisse') & (ucsdPitcherData.TaggedPitchType == 'Fastball')]
sobesFB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Joe Soberon') & ((ucsdPitcherData.TaggedPitchType == 'Fastball') | (ucsdPitcherData.TaggedPitchType == 'Sinker'))]
slothFB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Seth Sumner') & (ucsdPitcherData.TaggedPitchType == 'Fastball')]
haseFB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Sam Hasegawa') & (ucsdPitcherData.TaggedPitchType == 'Fastball')]
cucciFB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Ryan Forcucci') & (ucsdPitcherData.TaggedPitchType == 'Fastball')]
seidFB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Spencer Seid') & (ucsdPitcherData.TaggedPitchType == 'Fastball')]
donovanFB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Donovan Chriss') & (ucsdPitcherData.TaggedPitchType == 'Fastball')]
gregsonFB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Nic Gregson') & (ucsdPitcherData.TaggedPitchType == 'Fastball')]
mitchellFB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Michael Mitchell') & (ucsdPitcherData.TaggedPitchType == 'Fastball')]
izaakFB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Izaak Martinez') & (ucsdPitcherData.TaggedPitchType == 'Fastball')]
antFB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Anthony Eyanson') & (ucsdPitcherData.TaggedPitchType == 'Fastball')]
arnuFB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Aren Alvarez') & (ucsdPitcherData.TaggedPitchType == 'Fastball')]
holtFB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Ethan Holt') & (ucsdPitcherData.TaggedPitchType == 'Fastball')]
gillyFB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Chris Gilmartin') & (ucsdPitcherData.TaggedPitchType == 'Fastball')]
crackFB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Nolan Mccracken') & (ucsdPitcherData.TaggedPitchType == 'Fastball')]
ucsdFBLst = [arnuFB, donovanFB, ernieFB, antFB, cucciFB, gillyFB, gregsonFB, haseFB, holtFB, izaakFB, crackFB, mitchellFB, rissasFB, seidFB, sobesFB, slothFB]

# %%
# Convert string data in form "hour:minute" to numerical form based on total minutes. For example, a value of 90 would be 
# equivalent to "1:30". "12:00" is represented as 0 for a RHP and 720 for a LHP to avoid skewing averages as RHP will have
# lower tiltpoint scores and LHP will have higher tiltpoint scores on fastballs
# Takes in a data frame and returns a series
def tiltConv(pitcherdf):
    hand = pitcherdf.PitcherThrows.iloc[0]
    def toTiltpoints(tilt):
        tilt = str(tilt)
        colonpos = tilt.find(':')
        tiltpts = 0
        if (hand == 'Right') & (int(tilt[:colonpos]) == 12):
            tiltpts += int(tilt[colonpos + 1:])
        else:
            tiltpts += (int(tilt[:colonpos]) * 60) + int(tilt[colonpos + 1:])
        return tiltpts
    tiltptseries = pitcherdf[pitcherdf.Tilt.notnull()].Tilt.apply(toTiltpoints)
    return tiltptseries

# Gets middle 95 percent of the data to eliminate outliers/misreads
def mid95mean(dataSeries):    
    serieslst = list(dataSeries)
    if len(serieslst) < 3:
        return np.mean(serieslst)
    lower = np.percentile(serieslst, 2.5)
    upper = np.percentile(serieslst, 97.5)
    getmid = lambda val: (val >= lower) & (val <= upper)
    midlst = list(filter(getmid, serieslst))
    return np.mean(midlst)

def createTable(pitcherdflst):
    fullData = []
    columns = ['Name', 'Count', 'Velocity', 'Spin Rate', 'Efficiency', 'Tilt', 'Vertical Break', 'Horizontal Break', 'Miss %', 'SLG %', 'Strike %', 'Hard Hit %']
    for pitcher in pitcherdflst:
        name = pitcher.Pitcher.iloc[0]
        count = pitcher.shape[0]
        if pitcher[(pitcher.PitchCall == 'StrikeSwinging') | (pitcher.PitchCall == 'Foul') | (pitcher.PitchCall == 'InPlay')].shape[0] == 0:
            missrate = "no swings"
        else:
            missrate = pitcher[pitcher.PitchCall == 'StrikeSwinging'].shape[0] / pitcher[(pitcher.PitchCall == 'StrikeSwinging') | (pitcher.PitchCall == 'Foul') | (pitcher.PitchCall == 'InPlay')].shape[0] * 100
            missrate = round(missrate, 2)
        if pitcher[pitcher.KorBB == 'Strikeout'].shape[0] + pitcher[pitcher.PitchCall == 'InPlay'].shape[0] == 0:
            slg = "no result"
        else:
            slg = (pitcher[pitcher.PlayResult == 'Single'].shape[0] + pitcher[pitcher.PlayResult == 'Double'].shape[0]*2 + pitcher[pitcher.PlayResult == 'Triple'].shape[0]*3 + pitcher[pitcher.PlayResult == 'HomeRun'].shape[0]*4) / (pitcher[pitcher.KorBB == 'Strikeout'].shape[0] + pitcher[pitcher.PitchCall == 'InPlay'].shape[0])
            slg = round(slg, 3)
        strike = pitcher[pitcher.PitchCall != 'BallCalled'].shape[0] / pitcher.shape[0] * 100
        if pitcher[(pitcher.ExitSpeed.notnull()) & (pitcher.PitchCall == 'InPlay')].shape[0] == 0:
            hardhit = "no BIP"
        else:
            hardhit = pitcher[(pitcher.ExitSpeed >= 95) & (pitcher.PitchCall == 'InPlay')].shape[0] / pitcher[(pitcher.ExitSpeed.notnull()) & (pitcher.PitchCall == 'InPlay')].shape[0] *100
            hardhit = round(hardhit, 2)
        velo = mid95mean(pitcher[pitcher.RelSpeed.notnull()].RelSpeed)
        spin = mid95mean(pitcher[pitcher.SpinRate.notnull()].SpinRate)
        efficiency = mid95mean(pitcher[pitcher.yt_Efficiency.notnull()].yt_Efficiency)
        tiltpoints = mid95mean(tiltConv(pitcher))
        tiltminutes = str(int(tiltpoints % 60))
        if int(tiltminutes) < 10:
            tiltminutes = "0" + tiltminutes
        tilt = str(int(tiltpoints // 60)) + ":" + tiltminutes
        vb = mid95mean(pitcher[pitcher.InducedVertBreak.notnull()].InducedVertBreak)
        hb = mid95mean(pitcher[pitcher.HorzBreak.notnull()].HorzBreak)
        pitcherlst = [name, count, round(velo, 1), int(round(spin, 0)), round(efficiency, 1), tilt, round(vb, 1), round(hb, 1), missrate, slg, round(strike, 2), hardhit]
        fullData.append(pitcherlst)
    table = pd.DataFrame(fullData, columns = columns)
    table = table.set_index('Name')
    return table

# %%
ucsdFBstats = createTable(ucsdFBLst)
ucsdFBstats
# Out:
#                   Count  Velocity  Spin Rate  Efficiency   Tilt  \
# Name
# Aren Alvarez         40      89.8       2227        99.0   1:33
# Donovan Chriss       56      87.9       2099        79.3   1:36
# Zack Ernisse        156      90.2       1920        99.4  10:54
# Anthony Eyanson     163      88.6       1889        89.2   0:50
# Ryan Forcucci       111      93.1       2264        98.9   1:30
# Chris Gilmartin       7      84.6       2020        99.5  11:15
# Nic Gregson         126      89.3       2404        84.2   0:58
# Sam Hasegawa         77      86.3       2110        64.8  11:51
# Ethan Holt           35      86.4       1692        66.7   1:30
# Izaak Martinez      222      86.8       2315        96.8  11:19
# Nolan Mccracken      25      90.9       2184        93.9   0:43
# Michael Mitchell    139      90.7       2284        80.0   0:20
# Ryan Rissas         104      88.0       2166        85.7  11:37
# Spencer Seid         77      88.1       1901        99.0  10:24
# ...

# %%
rissasSL = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Ryan Rissas') & (ucsdPitcherData.TaggedPitchType == 'Slider')]
ernieSL = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Zack Ernisse') & (ucsdPitcherData.TaggedPitchType == 'Slider')]
sobesSL = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Joe Soberon') & (ucsdPitcherData.TaggedPitchType == 'Slider')]
slothSL = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Seth Sumner') & (ucsdPitcherData.TaggedPitchType == 'Slider')]
haseSL = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Sam Hasegawa') & (ucsdPitcherData.TaggedPitchType == 'Slider')]
cucciSL = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Ryan Forcucci') & (ucsdPitcherData.TaggedPitchType == 'Slider')]
seidSL = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Spencer Seid') & (ucsdPitcherData.TaggedPitchType == 'Slider')]
donovanSL = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Donovan Chriss') & (ucsdPitcherData.TaggedPitchType == 'Slider')]
gregsonSL = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Nic Gregson') & (ucsdPitcherData.TaggedPitchType == 'Slider')]
mitchellSL = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Michael Mitchell') & (ucsdPitcherData.TaggedPitchType == 'Slider')]
izaakSL = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Izaak Martinez') & ((ucsdPitcherData.TaggedPitchType == 'Curveball') | (ucsdPitcherData.TaggedPitchType == 'Slider'))]
arnuSL = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Aren Alvarez') & (ucsdPitcherData.TaggedPitchType == 'Slider')]
holtSL = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Ethan Holt') & (ucsdPitcherData.TaggedPitchType == 'Slider')]
gillySL = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Chris Gilmartin') & (ucsdPitcherData.TaggedPitchType == 'Slider')]
crackSL = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Nolan Mccracken') & (ucsdPitcherData.TaggedPitchType == 'Slider')]
ucsdSLLst = [arnuSL, donovanSL, ernieSL, cucciSL, gillySL, gregsonSL, haseSL, holtSL, izaakSL, crackSL, mitchellSL, rissasSL, seidSL, sobesSL, slothSL]

SL = createTable(ucsdSLLst)
SL
# Out:
#                   Count  Velocity  Spin Rate  Efficiency   Tilt  \
# Name
# Aren Alvarez         57      79.8       2556        15.8   8:07
# Donovan Chriss       49      77.4       2141        38.4   9:17
# Zack Ernisse         60      83.0       2391        42.9   5:00
# Ryan Forcucci        55      82.9       2401        27.7   8:36
# Chris Gilmartin       4      74.2       2028        16.0   3:00
# Nic Gregson          70      82.6       2560        17.0   5:02
# Sam Hasegawa         20      77.2       2259        31.5   3:13
# Ethan Holt           29      79.5       1769        20.5  10:05
# Izaak Martinez       37      78.0       2229        19.9   3:30
# Nolan Mccracken      58      80.5       2536        38.7   8:47
# Michael Mitchell     45      77.3       2400        57.3   7:12
# Ryan Rissas          58      78.5       2545        36.9   5:37
# Spencer Seid          7      77.0       2162        39.5   3:57
# Joe Soberon          33      80.2       2230        17.4   5:21
# ...

# %%
rissasCH = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Ryan Rissas') & (ucsdPitcherData.TaggedPitchType == 'Changeup')]
ernieCH = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Zack Ernisse') & (ucsdPitcherData.TaggedPitchType == 'Changeup')]
sobesCH = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Joe Soberon') & (ucsdPitcherData.TaggedPitchType == 'Changeup')]
slothCH = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Seth Sumner') & (ucsdPitcherData.TaggedPitchType == 'Changeup')]
#haseCH = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Sam Hasegawa') & (ucsdPitcherData.TaggedPitchType == 'Changeup')]
#cucciCH = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Ryan Forcucci') & (ucsdPitcherData.TaggedPitchType == 'Changeup')]
donovanCH = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Donovan Chriss') & (ucsdPitcherData.TaggedPitchType == 'Changeup')]
gregsonCH = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Nic Gregson') & (ucsdPitcherData.TaggedPitchType == 'Changeup')]
mitchellCH = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Michael Mitchell') & (ucsdPitcherData.TaggedPitchType == 'Changeup')]
izaakCH = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Izaak Martinez') & (ucsdPitcherData.TaggedPitchType == 'Changeup')]
antSP = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Anthony Eyanson') & (ucsdPitcherData.TaggedPitchType == 'Splitter')]
arnuCH = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Aren Alvarez') & (ucsdPitcherData.TaggedPitchType == 'Changeup')]
ucsdCHLst = [arnuCH, donovanCH, ernieCH, antSP, gregsonCH, izaakCH, mitchellCH, rissasCH, sobesCH, slothCH]

CH = createTable(ucsdCHLst)
CH
# Out:
#                   Count  Velocity  Spin Rate  Efficiency   Tilt  \
# Name
# Aren Alvarez          5      84.2       2135        98.2   1:52
# Donovan Chriss        7      83.1       1918        83.8   2:24
# Zack Ernisse         11      83.2       1753        93.8  10:05
# Anthony Eyanson      22      79.5        422        82.3   0:49
# Nic Gregson           6      82.2       1659        95.7   1:33
# Izaak Martinez       12      78.1       1489        92.6  11:00
# Michael Mitchell      8      83.9       1775        58.7   0:51
# Ryan Rissas           6      84.2       1687        92.1  10:45
# Joe Soberon          19      77.0       1430        89.3   2:12
# Seth Sumner          36      79.8       1768        92.9   2:30
#
#                   Vertical Break  Horizontal Break  Miss %      SLG %  \
# Name
# Aren Alvarez                10.7              14.0   25.00  no result
# Donovan Chriss               6.2              12.0    0.00        0.0
# ...

# %%
slothCB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Seth Sumner') & (ucsdPitcherData.TaggedPitchType == 'Curveball')]
cucciCB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Ryan Forcucci') & (ucsdPitcherData.TaggedPitchType == 'Curveball')]
gregsonCB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Nic Gregson') & (ucsdPitcherData.TaggedPitchType == 'Curveball')]
antCB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Anthony Eyanson') & (ucsdPitcherData.TaggedPitchType == 'Curveball')]
arnuCB = ucsdPitcherData[(ucsdPitcherData.Pitcher == 'Aren Alvarez') & (ucsdPitcherData.TaggedPitchType == 'Curveball')]
ucsdCBLst = [arnuCB, antCB, cucciCB, gregsonCB, slothCB]

CB = createTable(ucsdCBLst)
CB
# Out:
#                  Count  Velocity  Spin Rate  Efficiency  Tilt  Vertical Break  \
# Name
# Aren Alvarez        14      74.0       2550        55.8  7:18            -6.9
# Anthony Eyanson    126      74.1       2315        82.7  6:51           -11.9
# Ryan Forcucci       11      77.2       2096        64.9  7:25            -6.4
# Nic Gregson         49      75.1       2648        65.8  6:43           -11.3
# Seth Sumner          8      70.4       2326        96.8  7:09           -10.4
#
#                  Horizontal Break  Miss %      SLG %  Strike % Hard Hit %
# Name
# Aren Alvarez                -10.0   33.33        0.5     42.86        0.0
# Anthony Eyanson              -8.1   50.00        0.2     62.70        0.0
# Ryan Forcucci                -9.3  100.00  no result     27.27     no BIP
# Nic Gregson                  -7.2   31.25      0.625     53.06      33.33
# Seth Sumner                 -10.7   25.00        0.0     62.50        0.0
